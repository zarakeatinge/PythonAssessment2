# %% [markdown]
# <a href="https://colab.research.google.com/github/zarakeatinge/PythonAssessment2/blob/main/Personal_Health_Record_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#---Section 1

# %%
#---Section 2

# %%
#---Section 3

# %%
#---Section 4

# %%
#---Questions
